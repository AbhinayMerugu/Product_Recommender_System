# %%
import pandas as pd
pd.set_option("display.max_rows",100)

# %%
df_elec=pd.read_csv("/content/All Electronics.csv.zip")

# %%
df_elec.shape
# Out:
# (9600, 9)

# %%
for i,x in enumerate(df_elec["discount_price"]):
   if isinstance(x, str):
         x = x.replace('₹', '').replace(',', '')
   df_elec["discount_price"][i]=float(x)
# Out:
# <ipython-input-54-0dcb9570ca24>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_elec["discount_price"][i]=float(x)

# %%
df_elec=df_elec[df_elec["discount_price"]>5000]

# %%
mobiles_df=df_elec[~df_elec["name"].str.contains("inches")]

# %%
mobiles_df["main_category"]="SmartDevices"
mobiles_df["sub_category"]="MobilePhones"
# Out:
# <ipython-input-57-ff915ec4710c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiles_df["main_category"]="SmartDevices"
# <ipython-input-57-ff915ec4710c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiles_df["sub_category"]="MobilePhones"

# %%
mobiles_df.reset_index(drop=True,inplace=True)

# %%
mobiles_df.shape
# Out:
# (833, 9)

# %%
for i,x in enumerate(mobiles_df['discount_price']):
  if x<15000:
    mobiles_df.loc[i,"Type"]="LowRangeMobile"
  elif x>15000 and x<35000:
    mobiles_df.loc[i,"Type"]="MidRangeMobile"
  elif x>35000 and x<70000:
    mobiles_df.loc[i,"Type"]="PremiumRangeMobile"
  elif x>70000:
    mobiles_df.loc[i,"Type"]="LuxuryRangeMobile"
# Out:
# <ipython-input-60-6e71cf846b05>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mobiles_df.loc[i,"Type"]="LowRangeMobile"

# %%
mobiles_df.head()
# Out:
#                                                 name main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  SmartDevices
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  SmartDevices
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  SmartDevices
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  SmartDevices
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  SmartDevices
#
#    sub_category                                              image  \
# 0  MobilePhones  https://m.media-amazon.com/images/I/81eM15lVcJ...
# 1  MobilePhones  https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 2  MobilePhones  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 3  MobilePhones  https://m.media-amazon.com/images/I/71V--WZVUI...
# 4  MobilePhones  https://m.media-amazon.com/images/I/81OZGH4fZi...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Redmi-Power-Black-128GB-...     4.0           965
# ...

# %%
df_hp=pd.read_csv("/content/Headphones.csv.zip")

# %%
df_hp.shape
# Out:
# (9600, 9)

# %%
import random
ind=[random.randint(0,df_hp.shape[0]+1) for _ in range(0,1200)]
ind=list(set(ind))
len(ind)
# Out:
# 1117

# %%
headphones_df=df_hp.iloc[ind,:]
headphones_df=headphones_df.reset_index(drop=True)
headphones_df.shape
# Out:
# (1117, 9)

# %%
headphones_df["main_category"]="Audio"

# %%
for i,x in enumerate(headphones_df["discount_price"]):
   if isinstance(x, str):
         x = x.replace('₹', '').replace(',', '')
   headphones_df.loc[i,"discount_price"]=float(x)

# %%
headphones_df['discount_price'].fillna(value=round(headphones_df['discount_price'].mean()+3000,2),inplace=True)
# Out:
# <ipython-input-68-1183cefea694>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   headphones_df['discount_price'].fillna(value=round(headphones_df['discount_price'].mean()+3000,2),inplace=True)
# <ipython-input-68-1183cefea694>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
for i,x in enumerate(headphones_df['discount_price']):
  if x<3000:
    headphones_df.loc[i,"Type"]="LowRangeHeadPhone"
  elif x>3000 and x<15000:
    headphones_df.loc[i,"Type"]="MidRangeHeadPhone"
  elif x>15000 and x<25000:
    headphones_df.loc[i,"Type"]="PremiumRangeHeadPhone"
  elif x>25000:
    headphones_df.loc[i,"Type"]="LuxuryRangeHeadPhone"

# %%
headphones_df.head()
# Out:
#                                                 name main_category  \
# 0  Zebronics Zeb - Paradise Wireless BT Headphone...         Audio
# 1  FEBTO Compatible Dolby Digital Sound Bomb Seri...         Audio
# 2  boAt Airdopes 141 Bluetooth Truly Wireless in ...         Audio
# 3  Wireless Bluetooth Headphones Earphones for On...         Audio
# 4  In-Ear TYPE-C PORT Headphone For OnePlus Nord ...         Audio
#
#   sub_category                                              image  \
# 0   Headphones  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1   Headphones  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2   Headphones  https://m.media-amazon.com/images/I/51HBom8xz7...
# 3   Headphones  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4   Headphones  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/ZEBRONICS-Zeb-Paradise-B...     3.7           124
# ...

# %%
df_wc=pd.read_csv("/content/Watches.csv.zip")

# %%
df_wc.shape
# Out:
# (19133, 9)

# %%
import random
ind=[random.randint(0,df_wc.shape[0]+1) for _ in range(0,1200)]
ind=list(set(ind))
len(ind)
# Out:
# 1165

# %%
watches_df=df_wc.iloc[ind,:]
watches_df=watches_df.reset_index(drop=True)
watches_df.shape
# Out:
# (1165, 9)

# %%
for i,x in enumerate(watches_df["discount_price"]):
   if isinstance(x, str):
         x = x.replace('₹', '').replace(',', '')
   watches_df.loc[i,"discount_price"]=float(x)

# %%
watches_df['discount_price'].fillna(value=round(watches_df['discount_price'].mean()+2000,2),inplace=True)
# Out:
# <ipython-input-76-3136d5d676ab>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   watches_df['discount_price'].fillna(value=round(watches_df['discount_price'].mean()+2000,2),inplace=True)
# <ipython-input-76-3136d5d676ab>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
for i,x in enumerate(watches_df['discount_price']):
  if x<3000:
    watches_df.loc[i,"Type"]="LowRangeWatch"
  elif x>3000 and x<15000:
    watches_df.loc[i,"Type"]="MidRangeWatch"
  elif x>15000 and x<25000:
    watches_df.loc[i,"Type"]="PremiumRangeWatch"
  elif x>25000:
    watches_df.loc[i,"Type"]="LuxuryRangeWatch"

# %%
watches_df.head()
# Out:
#                                                 name main_category  \
# 0   Maxima Analog Black Dial Women's Watch-52363CALI   accessories
# 1  Lacoste Cannes Analog Silver Dial Women's Watc...   accessories
# 2  ORAYAN Analogue Women's Watch (Black Dial Blac...   accessories
# 3  CRESTELLO Women's Watch (Stainless Steel Chain...   accessories
# 4     TIMEX Analog Blue Dial Women's Watch-TWTL10302   accessories
#
#   sub_category                                              image  \
# 0      Watches  https://m.media-amazon.com/images/I/71eR1zuNQ9...
# 1      Watches  https://m.media-amazon.com/images/I/71mm7ahNOO...
# 2      Watches  https://m.media-amazon.com/images/I/51AI4EiWAE...
# 3      Watches  https://m.media-amazon.com/images/I/71kiCC2Xtu...
# 4      Watches  https://m.media-amazon.com/images/I/51U5HJRS0x...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Maxima-Analog-Black-Wome...     4.5             2
# ...

# %%
telivision_df=pd.read_csv("/content/Televisions.csv")

# %%
telivision_df['main_category']="TV"

# %%
telivision_df.shape
# Out:
# (1104, 9)

# %%
for i,x in enumerate(telivision_df["discount_price"]):
   if isinstance(x, str):
         x = x.replace('₹', '').replace(',', '')
   telivision_df.loc[i,"discount_price"]=float(x)

# %%
telivision_df["discount_price"].fillna(value=round(telivision_df["discount_price"].mean()+4000,2),inplace=True)
# Out:
# <ipython-input-83-6e9a03ab2e6f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   telivision_df["discount_price"].fillna(value=round(telivision_df["discount_price"].mean()+4000,2),inplace=True)
# <ipython-input-83-6e9a03ab2e6f>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
for i,x in enumerate(telivision_df['discount_price']):
  if x<25000:
    telivision_df.loc[i,"Type"]="LowRangeTV"
  elif x>25000 and x<50000:
   telivision_df.loc[i,"Type"]="MidRangeTV"
  elif x>50000 and x<100000:
    telivision_df.loc[i,"Type"]="PremiumRangeTV"
  elif x>100000:
   telivision_df.loc[i,"Type"]="LuxuryRangeTV"

# %%
telivision_df.head()
# Out:
#                                                 name main_category  \
# 0  Samsung 80 cm (32 Inches) Wondertainment Serie...            TV
# 1  MI 80 cm (32 inches) 5A Series HD Ready Smart ...            TV
# 2  Redmi 80 cm (32 inches) Android 11 Series HD R...            TV
# 3  OnePlus 138 cm (55 inches) Y Series 4K Ultra H...            TV
# 4  OnePlus 80 cm (32 inches) Y Series HD Ready LE...            TV
#
#   sub_category                                              image  \
# 0  Televisions  https://m.media-amazon.com/images/W/IMAGERENDE...
# 1  Televisions  https://m.media-amazon.com/images/W/IMAGERENDE...
# 2  Televisions  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3  Televisions  https://m.media-amazon.com/images/W/IMAGERENDE...
# 4  Televisions  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Samsung-Inches-Wondertai...     4.2         8,877
# ...

# %%
sw_df=pd.read_csv("/content/Sportswear.csv.zip")

# %%
import random
ind=[random.randint(0,sw_df.shape[0]+1) for _ in range(0,1200)]
ind=list(set(ind))
len(ind)
# Out:
# 1118

# %%
shoes_df=sw_df.iloc[ind,:]
shoes_df=shoes_df.reset_index(drop=True)
shoes_df.shape
# Out:
# (1118, 9)

# %%
shoes_df.shape
# Out:
# (1118, 9)

# %%
shoes_df["main_category"]="Sportswear"
shoes_df["sub_category"]="Shoes"

# %%
for i,x in enumerate(shoes_df["discount_price"]):
   if isinstance(x, str):
         x = x.replace('₹', '').replace(',', '')
   shoes_df.loc[i,"discount_price"]=float(x)

# %%
shoes_df["discount_price"].fillna(value=round(shoes_df["discount_price"].mean()+5000,2),inplace=True)
# Out:
# <ipython-input-92-7e7f8d5222d8>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shoes_df["discount_price"].fillna(value=round(shoes_df["discount_price"].mean()+5000,2),inplace=True)
# <ipython-input-92-7e7f8d5222d8>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
shoes_df["discount_price"].max()
# Out:
# 19795.0

# %%
for i,x in enumerate(shoes_df['discount_price']):
  if x<2500:
    shoes_df.loc[i,"Type"]="LowRangeShoe"
  elif x>2500 and x<7000:
    shoes_df.loc[i,"Type"]="MidRangeShoe"
  elif x>7000 and x<15000:
    shoes_df.loc[i,"Type"]="PremiumRangeShoe"
  elif x>15000:
   shoes_df.loc[i,"Type"]="LuxuryRangeShoe"

# %%
shoes_df.head()
# Out:
#                                                 name main_category  \
# 0                  Campus Men's Maxico Running Shoes    Sportswear
# 1  Nike Unisex Classic II Cushion Over-The-Calf S...    Sportswear
# 2                         new balance Men's Mtl574na    Sportswear
# 3                    Sparx Mens Sx0500g Running Shoe    Sportswear
# 4          Under Armour Men's Verge Low Hiking Boots    Sportswear
#
#   sub_category                                              image  \
# 0        Shoes  https://m.media-amazon.com/images/I/81Pk4RiSKq...
# 1        Shoes  https://m.media-amazon.com/images/I/81qEEW7hx1...
# 2        Shoes  https://m.media-amazon.com/images/W/IMAGERENDE...
# 3        Shoes  https://m.media-amazon.com/images/I/41qqR0F0Th...
# 4        Shoes  https://m.media-amazon.com/images/I/81qHx3-5Lb...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Campus-Maxico-MODBLU-BLU...     3.9        20,423
# ...

# %%
products_df=pd.concat([mobiles_df,headphones_df,watches_df,telivision_df,shoes_df],ignore_index=True)

# %%
products_df.head()
# Out:
#                                                 name main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  SmartDevices
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  SmartDevices
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  SmartDevices
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  SmartDevices
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  SmartDevices
#
#    sub_category                                              image  \
# 0  MobilePhones  https://m.media-amazon.com/images/I/81eM15lVcJ...
# 1  MobilePhones  https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 2  MobilePhones  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 3  MobilePhones  https://m.media-amazon.com/images/I/71V--WZVUI...
# 4  MobilePhones  https://m.media-amazon.com/images/I/81OZGH4fZi...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Redmi-Power-Black-128GB-...     4.0           965
# ...

# %%
images=products_df["image"]

# %%
images.head()
# Out:
# 0    https://m.media-amazon.com/images/I/81eM15lVcJ...
# 1    https://m.media-amazon.com/images/I/71AvQd3Vzq...
# 2    https://m.media-amazon.com/images/I/81I3w4J6yj...
# 3    https://m.media-amazon.com/images/I/71V--WZVUI...
# 4    https://m.media-amazon.com/images/I/81OZGH4fZi...
# Name: image, dtype: object

# %%
for i,x in enumerate(images):
  if "images/W/IMAGERENDERING_521856-T2/" in x:
      images[i]=x.replace("images/W/IMAGERENDERING_521856-T2/","")
  elif "images/W/IMAGERENDERING_521856-T1/" in x:
      images[i]=x.replace("images/W/IMAGERENDERING_521856-T1/","")

# %%
link=products_df["link"]

# %%
link.head()
# Out:
# 0    https://www.amazon.in/Redmi-Power-Black-128GB-...
# 1    https://www.amazon.in/OnePlus-Nord-Lite-128GB-...
# 2    https://www.amazon.in/Samsung-Mystique-Storage...
# 3    https://www.amazon.in/OnePlus-Nord-Black-128GB...
# 4    https://www.amazon.in/Redmi-Power-Sporty-Orang...
# Name: link, dtype: object

# %%
products_df.drop(columns=["image","link","ratings","no_of_ratings","discount_price","actual_price"],inplace=True)

# %%
products_df.head(10)
# Out:
#                                                 name main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  SmartDevices
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  SmartDevices
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  SmartDevices
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  SmartDevices
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  SmartDevices
# 5  Samsung Galaxy M33 5G (Emerald Brown, 6GB, 128...  SmartDevices
# 6  realme narzo 50A Prime (Flash Black, 4GB RAM+6...  SmartDevices
# 7  Redmi A1 (Light Blue, 2GB RAM, 32GB Storage) |...  SmartDevices
# 8  OnePlus Nord CE 2 Lite 5G (Blue Tide, 8GB RAM,...  SmartDevices
# 9  Redmi A1 (Black, 2GB RAM, 32GB Storage) | Segm...  SmartDevices
#
#    sub_category            Type
# 0  MobilePhones  LowRangeMobile
# 1  MobilePhones  MidRangeMobile
# 2  MobilePhones  MidRangeMobile
# 3  MobilePhones  MidRangeMobile
# 4  MobilePhones  LowRangeMobile
# ...

# %%
products_df.shape
# Out:
# (5337, 6)

# %%
col=["main_category","sub_category",'Type']
def fun(x):
  for i,y in enumerate(products_df[x]):
    l=[]
    l.append(y)
    products_df.loc[i,x]=l


for c in col:
     fun(c)

# %%
names=products_df['name']

# %%
names.head()
# Out:
# 0    Redmi 10 Power (Power Black, 8GB RAM, 128GB St...
# 1    OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...
# 2    Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...
# 3    OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...
# 4    Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...
# Name: name, dtype: object

# %%
products_df["Features"]=products_df["name"].apply(lambda x:x.split(" "))

# %%
for i in range(len(products_df["Features"])):
     for j in range(len(products_df["Features"][i])):
             if "(" in products_df["Features"][i][j]:
                 products_df["Features"][i][j]=products_df["Features"][i][j].replace("(","")
             elif ")" in products_df["Features"][i][j]:
                 products_df["Features"][i][j]=products_df["Features"][i][j].replace(")","")
             elif "," in products_df["Features"][i][j]:
                 products_df["Features"][i][j]=products_df["Features"][i][j].replace(",","")

# %%
products_df.head()
# Out:
#                                                 name   main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  [SmartDevices]
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  [SmartDevices]
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  [SmartDevices]
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  [SmartDevices]
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  [SmartDevices]
#
#      sub_category              Type  \
# 0  [MobilePhones]  [LowRangeMobile]
# 1  [MobilePhones]  [MidRangeMobile]
# 2  [MobilePhones]  [MidRangeMobile]
# 3  [MobilePhones]  [MidRangeMobile]
# 4  [MobilePhones]  [LowRangeMobile]
#
#                                             Features
# 0  [Redmi, 10, Power, Power, Black, 8GB, RAM, 128...
# 1  [OnePlus, Nord, CE, 2, Lite, 5G, Blue, Tide, 6...
# 2  [Samsung, Galaxy, M33, 5G, Mystique, Green, 6G...
# 3  [OnePlus, Nord, CE, 2, Lite, 5G, Black, Dusk, ...
# 4  [Redmi, 10, Power, Sporty, Orange, 8GB, RAM, 1...

# %%
products_df["Tags"]=products_df["main_category"]+products_df["sub_category"]+products_df["Type"]+products_df["Features"]

# %%
products_df.head()
# Out:
#                                                 name   main_category  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...  [SmartDevices]
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...  [SmartDevices]
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...  [SmartDevices]
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...  [SmartDevices]
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...  [SmartDevices]
#
#      sub_category              Type  \
# 0  [MobilePhones]  [LowRangeMobile]
# 1  [MobilePhones]  [MidRangeMobile]
# 2  [MobilePhones]  [MidRangeMobile]
# 3  [MobilePhones]  [MidRangeMobile]
# 4  [MobilePhones]  [LowRangeMobile]
#
#                                             Features  \
# 0  [Redmi, 10, Power, Power, Black, 8GB, RAM, 128...
# 1  [OnePlus, Nord, CE, 2, Lite, 5G, Blue, Tide, 6...
# 2  [Samsung, Galaxy, M33, 5G, Mystique, Green, 6G...
# 3  [OnePlus, Nord, CE, 2, Lite, 5G, Black, Dusk, ...
# 4  [Redmi, 10, Power, Sporty, Orange, 8GB, RAM, 1...
#
# ...

# %%
products1_df=products_df[["name","Tags"]]

# %%
products1_df.head()
# Out:
#                                                 name  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...
#
#                                                 Tags
# 0  [SmartDevices, MobilePhones, LowRangeMobile, R...
# 1  [SmartDevices, MobilePhones, MidRangeMobile, O...
# 2  [SmartDevices, MobilePhones, MidRangeMobile, S...
# 3  [SmartDevices, MobilePhones, MidRangeMobile, O...
# 4  [SmartDevices, MobilePhones, LowRangeMobile, R...

# %%
products1_df["Tags"]=products1_df["Tags"].apply(lambda x:" ".join([str(i) for i in x]))
# Out:
# <ipython-input-115-4a18a2d028ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products1_df["Tags"]=products1_df["Tags"].apply(lambda x:" ".join([str(i) for i in x]))

# %%
"""from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()"""
# Out:
# 'from nltk.stem.porter import PorterStemmer\nps=PorterStemmer()'

# %%
"""def stem(text):
  l=[]
  for i in text.split(" "):
    l.append(ps.stem(i))
  return " ".join(l)"""
# Out:
# 'def stem(text):\n  l=[]\n  for i in text.split(" "):\n    l.append(ps.stem(i))\n  return " ".join(l)'

# %%
products1_df["Tags"]=products1_df["Tags"].apply(lambda x:x.lower())
# Out:
# <ipython-input-118-9f476f5c076a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products1_df["Tags"]=products1_df["Tags"].apply(lambda x:x.lower())

# %%
products1_df.head()
# Out:
#                                                 name  \
# 0  Redmi 10 Power (Power Black, 8GB RAM, 128GB St...
# 1  OnePlus Nord CE 2 Lite 5G (Blue Tide, 6GB RAM,...
# 2  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...
# 3  OnePlus Nord CE 2 Lite 5G (Black Dusk, 6GB RAM...
# 4  Redmi 10 Power (Sporty Orange, 8GB RAM, 128GB ...
#
#                                                 Tags
# 0  smartdevices mobilephones lowrangemobile redmi...
# 1  smartdevices mobilephones midrangemobile onepl...
# 2  smartdevices mobilephones midrangemobile samsu...
# 3  smartdevices mobilephones midrangemobile onepl...
# 4  smartdevices mobilephones lowrangemobile redmi...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=1000,stop_words="english")

# %%
vectors=cv.fit_transform(products1_df["Tags"]).toarray()
vectors.shape
# Out:
# (5337, 1000)

# %%
features=cv.get_feature_names_out()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
def recommend(product):
     product_index=products1_df[products1_df["name"]==product].index[0]
     sim=list(enumerate(similarity[product_index]))
     sim.sort(reverse=True,key=lambda x: x[1])
     rec=sim[1:6]
     for x in rec:
      print(products1_df["name"][x[0]])

# %%
for i in range(200):
      x=products1_df["name"][i]
      products1_df.loc[i,'name']=x.split("(")[0]

# %%
names_trim=products1_df["name"]

# %%
import pickle
pickle.dump(names,open("names.pkl","wb"))

# %%
pickle.dump(names_trim,open("names_trim.pkl","wb"))

# %%
similarity.shape
# Out:
# (5337, 5337)

# %%
pickle.dump(images,open("images1.pkl","wb"))

# %%
pickle.dump(link,open("link.pkl","wb"))

# %%
pickle.dump(similarity,open("similarity1.pkl","wb"))
